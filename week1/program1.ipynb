# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a45a0-cmyk/python/blob/main/week1/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(type(8*2))
# Out:
# <class 'int'>

# %%
print("python")
# Out:
# python

# %%
for i in range(0,5,2):
  print(i)
# Out:
# 0
# 2
# 4

# %%
a=0.05
print(type(a))
# Out:
# <class 'float'>

# %%
a=int(input("Enter number:"))
b=int(input("Enter another number:"))
print(a,b)
print(a+b)
# Out:
# Enter number:10
# Enter another number:15
# 10 15
# 25

# %%
k=input()
print(k)
# Out:
# 90
# 90

# %%
s=input()
print(s)
# Out:
# bts
# bts

# %% [markdown]
# c//d gives integer value of quoteint
# c/d gives float value of quotient

# %%
c=int(input("Enter value of a:"))
d=int(input("Enter value of b:"))
print(c//d)
print(c/d)
print(c+d)
print(c-d)
print(c*d)
print(c%d)
# Out:
# Enter value of a:13
# Enter value of b:2
# 6
# 6.5
# 15
# 11
# 26
# 1

# %%
if c>d:
  print("c is greater then d")
else:
  print("c is smaller than d")
# Out:
# c is greater then d

# %%
a=int(input("Enter a number:"))
if a%2==0:
  print("Even Number")
else:
  print("Odd Number")
# Out:
# Enter a number:5
# Odd Number

# %%
a=int(input("Enter a number:"))
if a==0:
  print("The given number is Zero")
if a>0:
  print("The given number is Positive")
if a<0:
  print("The given number is Negative")
# Out:
# Enter a number:0
# The given number is Zero

# %%
a=int(input("Enter number:"))
k=0;
while a!=0:
  k=k+a%10
  a=a//10
print(k)
# Out:
# Enter number:-128

# %%
a=int(input("Enter a number:"))
k=0;
while a!=0:
  a=a//10
  k=k+1
print(k)
