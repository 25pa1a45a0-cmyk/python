# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a45a0-cmyk/python/blob/main/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STRINGS

# %% [markdown]
# Set of characters is called a string
# String is immutable

# %%
#Most useful Method
a="hello python code"
b=a.split()
print(b)
# Out:
# ['hello', 'python', 'code']

# %%
c=" ".join(b)
print(c)
c="".join(b)
print(c)
# Out:
# hello python code
# hellopythoncode

# %%
#Strip() is used to remove unnecessary spaces in the string
x=" ai & ds "
print(x.strip())
# Out:
# ai & ds

# %% [markdown]
# String Methods
# 1.split()
# 2.join()
# 3.upper() and lower()
# 4.strip()
# 5.replace()
# 6.find()
# 7.count()

# %%
text="Python is easy"
print(text.split())
print(text.split(","))
print(text.upper())
print(text.lower())
print(text.replace("easy","hard"))
print(text.find("hard"))
print(text.count("is"))
print(text)
# Out:
# ['Python', 'is', 'easy']
# ['Python is easy']
# PYTHON IS EASY
# python is easy
# Python is hard
# -1
# 1
# Python is easy

# %%
#Slicing can be done through indexing
a="hello"
b="hello"
print(a[0])
print(a[-1])
print(a[1:3])
print(a[-4:-1])
print(a[1:4:2])
print(a[::-1])
print(a[::])
print(a[::-2])
b=a[1:3]
print(b)
print(sorted(a))
# Out:
# h
# o
# el
# ell
# el
# olleh
# hello
# olh
# el
# ['e', 'h', 'l', 'l', 'o']
